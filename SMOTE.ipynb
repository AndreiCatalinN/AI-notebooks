# %% [markdown]
# Learning about synthetic minority oversampling technique

# %%
import pandas as pd
import seaborn as sb
df = pd.read_csv('TEM27.20260331220832.csv')
df.head(10)
df_sample = df.head(200)

# %%
sb.countplot(df_sample["Statistic Label"])

# %%
from sklearn.utils import resample
unexpired_pto = df[([df'expired_pto']==)]
expire
